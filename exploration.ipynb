# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error as mae

# %%
df = pd.read_csv('./data/dataset_analysed.csv', dtype={'StateOfBuilding' : object})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114504 entries, 0 to 114503
# Data columns (total 34 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Url                114504 non-null  object
#  1   BathroomCount      114504 non-null  float64
#  2   BedroomCount       114504 non-null  int64
#  3   ConstructionYear   66591 non-null   float64
#  4   Country            114504 non-null  object
#  5   District           114504 non-null  object
#  6   Fireplace          114504 non-null  float64
#  7   FloodingZone       56440 non-null   object
#  8   Furnished          114504 non-null  float64
#  9   Garden             114504 non-null  float64
#  10  GardenArea         114504 non-null  float64
#  11  Kitchen            64464 non-null   object
#  12  LivingArea         101071 non-null  float64
#  13  Locality           114501 non-null  object
#  14  MonthlyCharges     12710 non-null   float64
#  15  NumberOfFacades    73777 non-null   float64
#  16  PEB                81957 non-null   object
#  17  PostalCode         114504 non-null  int64
#  18  Price              114504 non-null  int64
#  19  PropertyId         114504 non-null  int64
#  20  Province           114504 non-null  object
#  21  Region             114504 non-null  object
#  22  RoomCount          31972 non-null   float64
#  23  ShowerCount        55074 non-null   float64
#  24  StateOfBuilding    78563 non-null   object
#  25  SubtypeOfProperty  114504 non-null  object
#  26  SurfaceOfPlot      55637 non-null   float64
#  27  SwimmingPool       114504 non-null  float64
#  28  Terrace            114504 non-null  float64
#  29  ToiletCount        114504 non-null  float64
#  30  TypeOfProperty     114504 non-null  int64
#  31  TypeOfSale         114504 non-null  object
#  32  MunicipalityName   114504 non-null  object
#  33  RefnisCode         114504 non-null  int64
# dtypes: float64(15), int64(6), object(13)
# memory usage: 29.7+ MB

# %%
df.drop(df[['Url', 'Country', 'MonthlyCharges','PropertyId','MunicipalityName']], axis='columns',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114504 entries, 0 to 114503
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   BathroomCount      114504 non-null  float64
#  1   BedroomCount       114504 non-null  int64
#  2   ConstructionYear   66591 non-null   float64
#  3   District           114504 non-null  object
#  4   Fireplace          114504 non-null  float64
#  5   FloodingZone       56440 non-null   object
#  6   Furnished          114504 non-null  float64
#  7   Garden             114504 non-null  float64
#  8   GardenArea         114504 non-null  float64
#  9   Kitchen            64464 non-null   object
#  10  LivingArea         101071 non-null  float64
#  11  Locality           114501 non-null  object
#  12  NumberOfFacades    73777 non-null   float64
#  13  PEB                81957 non-null   object
#  14  PostalCode         114504 non-null  int64
#  15  Price              114504 non-null  int64
#  16  Province           114504 non-null  object
#  17  Region             114504 non-null  object
#  18  RoomCount          31972 non-null   float64
#  19  ShowerCount        55074 non-null   float64
#  20  StateOfBuilding    78563 non-null   object
#  21  SubtypeOfProperty  114504 non-null  object
#  22  SurfaceOfPlot      55637 non-null   float64
#  23  SwimmingPool       114504 non-null  float64
#  24  Terrace            114504 non-null  float64
#  25  ToiletCount        114504 non-null  float64
#  26  TypeOfProperty     114504 non-null  int64
#  27  TypeOfSale         114504 non-null  object
#  28  RefnisCode         114504 non-null  int64
# dtypes: float64(14), int64(5), object(10)
# memory usage: 25.3+ MB

# %%
df2 = df.where(df['FloodingZone'] == None)
df2
# Out:
#         BathroomCount  BedroomCount  ConstructionYear District  Fireplace  \
# 0                 NaN           NaN               NaN      NaN        NaN
# 1                 NaN           NaN               NaN      NaN        NaN
# 2                 NaN           NaN               NaN      NaN        NaN
# 3                 NaN           NaN               NaN      NaN        NaN
# 4                 NaN           NaN               NaN      NaN        NaN
# ...               ...           ...               ...      ...        ...
# 114499            NaN           NaN               NaN      NaN        NaN
# 114500            NaN           NaN               NaN      NaN        NaN
# 114501            NaN           NaN               NaN      NaN        NaN
# 114502            NaN           NaN               NaN      NaN        NaN
# 114503            NaN           NaN               NaN      NaN        NaN
#
#        FloodingZone  Furnished  Garden  GardenArea Kitchen  ...  ShowerCount  \
# 0               NaN        NaN     NaN         NaN     NaN  ...          NaN
# 1               NaN        NaN     NaN         NaN     NaN  ...          NaN
# 2               NaN        NaN     NaN         NaN     NaN  ...          NaN
# 3               NaN        NaN     NaN         NaN     NaN  ...          NaN
# 4               NaN        NaN     NaN         NaN     NaN  ...          NaN
# ...             ...        ...     ...         ...     ...  ...          ...
# 114499          NaN        NaN     NaN         NaN     NaN  ...          NaN
# 114500          NaN        NaN     NaN         NaN     NaN  ...          NaN
# 114501          NaN        NaN     NaN         NaN     NaN  ...          NaN
# 114502          NaN        NaN     NaN         NaN     NaN  ...          NaN
# 114503          NaN        NaN     NaN         NaN     NaN  ...          NaN
#
#        StateOfBuilding  SubtypeOfProperty SurfaceOfPlot  SwimmingPool  \
# 0                  NaN                NaN           NaN           NaN
# 1                  NaN                NaN           NaN           NaN
# 2                  NaN                NaN           NaN           NaN
# 3                  NaN                NaN           NaN           NaN
# 4                  NaN                NaN           NaN           NaN
# ...                ...                ...           ...           ...
# 114499             NaN                NaN           NaN           NaN
# 114500             NaN                NaN           NaN           NaN
# 114501             NaN                NaN           NaN           NaN
# 114502             NaN                NaN           NaN           NaN
# 114503             NaN                NaN           NaN           NaN
#
#         Terrace ToiletCount TypeOfProperty  TypeOfSale  RefnisCode
# 0           NaN         NaN            NaN         NaN         NaN
# 1           NaN         NaN            NaN         NaN         NaN
# 2           NaN         NaN            NaN         NaN         NaN
# 3           NaN         NaN            NaN         NaN         NaN
# 4           NaN         NaN            NaN         NaN         NaN
# ...         ...         ...            ...         ...         ...
# 114499      NaN         NaN            NaN         NaN         NaN
# 114500      NaN         NaN            NaN         NaN         NaN
# 114501      NaN         NaN            NaN         NaN         NaN
# 114502      NaN         NaN            NaN         NaN         NaN
# 114503      NaN         NaN            NaN         NaN         NaN
#
# [114504 rows x 29 columns]

# %%
df.dropna(subset=['LivingArea'],inplace=True)
df.update(df['ConstructionYear'].fillna(value=med))

# %%
df[['Price', 'BedroomCount','Garden','GardenArea','LivingArea','Furnished','NumberOfFacades','ConstructionYear']].corr()
# Out:
#                      Price  BedroomCount    Garden  GardenArea  LivingArea  \
# Price             1.000000      0.386786  0.051441    0.105722    0.463487
# BedroomCount      0.386786      1.000000  0.175669    0.108229    0.595088
# Garden            0.051441      0.175669  1.000000    0.191400    0.132543
# GardenArea        0.105722      0.108229  0.191400    1.000000    0.130622
# LivingArea        0.463487      0.595088  0.132543    0.130622    1.000000
# Furnished         0.042954     -0.003375  0.000437    0.011214   -0.009177
# NumberOfFacades   0.202627      0.218856  0.105301    0.110144    0.231511
# ConstructionYear -0.051519     -0.184821 -0.116042   -0.052476   -0.174914
#
#                   Furnished  NumberOfFacades  ConstructionYear
# Price              0.042954         0.202627         -0.051519
# BedroomCount      -0.003375         0.218856         -0.184821
# Garden             0.000437         0.105301         -0.116042
# GardenArea         0.011214         0.110144         -0.052476
# LivingArea        -0.009177         0.231511         -0.174914
# Furnished          1.000000        -0.022494         -0.023155
# NumberOfFacades   -0.022494         1.000000          0.014627
# ConstructionYear  -0.023155         0.014627          1.000000

# %%
y = df['Price'].values
X = df[['ConstructionYear','LivingArea','BedroomCount']].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=42, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor as RFR

regressor = RFR(max_depth=2)

regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2)

# %%
regressor.score(X_train, y_train)
# Out:
# 0.24918281187073477

# %%
regressor.predict(X_train)
# Out:
# array([260843.04291487, 846410.80415042, 420712.5150098 , ...,
#        260843.04291487, 260843.04291487, 426182.62136992])

# %%
mae(y_train, regressor.predict(X_train))
# Out:
# np.float64(184376.62902925524)
